# %%
from experiments_utils import run_maybe_remotely
from sbibm_unle_extra.unle import run as run_unle

# %%
### SUNLE with DIVI
for seed in (1, 2, 3):
    for task in ("slcp", "two_moons", "lotka_volterra", "gaussian_linear_uniform",):
        for ns in (
            (100,) * 10,
            (1000,) * 10,
            (10000,) * 10,
        ):
            for no in list(range(1, 10)):
                _ = run_maybe_remotely(
                    run_unle,
                    folder_name="icml",
                    experience_name="sunle",
                    use_slurm=True,
                    slurm_kwargs={},
                    task=task,
                    num_samples=ns,
                    num_observation=no,
                    num_smc_steps=5,
                    num_mala_steps=50,
                    use_warm_start=True,
                    learning_rate=0.001 if task == "lotka_volterra" else 0.01,
                    max_iter=10 if task=="gaussian_linear_uniform" and (ns==(100,)*10 or ns==(1000,)*10) else 500,
                    weight_decay=0.1,
                    random_seed=seed,
                    sampler="mala",
                    num_particles=1000,
                    batch_size=1000,
                    num_posterior_samples=10000,
                    use_nuts=False,
                    init_proposal="prior",
                    noise_injection_val=0.0005,
                    proposal="data",
                    inference_sampler="mala",
                    ebm_model_type="likelihood",
                    inference_proposal="prior",
                    use_data_from_past_rounds=True,
                    inference_num_warmup_steps=500,
                    exchange_mcmc_inner_sampler_num_steps=100,
                    evaluate_posterior=True,
                    estimate_loss=False,
                    estimate_log_normalizer=True
                )
# Out:
# Submitted batch job 3304337
# Submitted batch job 3304338
# Submitted batch job 3304339
# Submitted batch job 3304340
# Submitted batch job 3304341
# Submitted batch job 3304342
# Submitted batch job 3304343
# Submitted batch job 3304344
# Submitted batch job 3304345
# Submitted batch job 3304346
# Submitted batch job 3304347
# Submitted batch job 3304348
# Submitted batch job 3304349
# Submitted batch job 3304350
# Submitted batch job 3304351
# Submitted batch job 3304352
# Submitted batch job 3304353
# Submitted batch job 3304354
# Submitted batch job 3304355
# Submitted batch job 3304356
# Submitted batch job 3304357
# Submitted batch job 3304358
# Submitted batch job 3304359
# Submitted batch job 3304360
# Submitted batch job 3304361
# Submitted batch job 3304362
# Submitted batch job 3304363
# Submitted batch job 3304364
# Submitted batch job 3304365
# Submitted batch job 3304366
# Submitted batch job 3304367
# Submitted batch job 3304368
# Submitted batch job 3304369
# Submitted batch job 3304370
# Submitted batch job 3304371
# Submitted batch job 3304372
# Submitted batch job 3304373
# Submitted batch job 3304374
# Submitted batch job 3304375
# Submitted batch job 3304376
# Submitted batch job 3304377
# Submitted batch job 3304378
# Submitted batch job 3304379
# Submitted batch job 3304380
# Submitted batch job 3304381
# Submitted batch job 3304382
# Submitted batch job 3304383
# Submitted batch job 3304384
# Submitted batch job 3304385
# Submitted batch job 3304386
# Submitted batch job 3304387
# Submitted batch job 3304388
# Submitted batch job 3304389
# Submitted batch job 3304390
# Submitted batch job 3304391
# Submitted batch job 3304392
# Submitted batch job 3304393
# Submitted batch job 3304394
# Submitted batch job 3304395
# Submitted batch job 3304396
# Submitted batch job 3304397
# Submitted batch job 3304398
# Submitted batch job 3304399
# Submitted batch job 3304400
# Submitted batch job 3304401
# Submitted batch job 3304402
# Submitted batch job 3304403
# Submitted batch job 3304404
# Submitted batch job 3304405
# Submitted batch job 3304406
# Submitted batch job 3304407
# Submitted batch job 3304408
# Submitted batch job 3304409
# Submitted batch job 3304410
# Submitted batch job 3304411
# Submitted batch job 3304412
# Submitted batch job 3304413
# Submitted batch job 3304414
# Submitted batch job 3304415
# Submitted batch job 3304416
# Submitted batch job 3304417
# Submitted batch job 3304418
# Submitted batch job 3304419
# Submitted batch job 3304420
# Submitted batch job 3304421
# Submitted batch job 3304422
# Submitted batch job 3304423
# Submitted batch job 3304424
# Submitted batch job 3304425
# Submitted batch job 3304426
# Submitted batch job 3304427
# Submitted batch job 3304428
# Submitted batch job 3304429
# Submitted batch job 3304430
# Submitted batch job 3304431
# Submitted batch job 3304432
# Submitted batch job 3304433
# Submitted batch job 3304434
# Submitted batch job 3304435
# Submitted batch job 3304436
# Submitted batch job 3304437
# Submitted batch job 3304438
# Submitted batch job 3304439
# Submitted batch job 3304440
# Submitted batch job 3304441
# Submitted batch job 3304442
# Submitted batch job 3304443
# Submitted batch job 3304444
# Submitted batch job 3304445
# Submitted batch job 3304446
# Submitted batch job 3304447
# Submitted batch job 3304448
# Submitted batch job 3304449
# Submitted batch job 3304450
# Submitted batch job 3304451
# Submitted batch job 3304452
# Submitted batch job 3304453
# Submitted batch job 3304454
# Submitted batch job 3304455
# Submitted batch job 3304456
# Submitted batch job 3304457
# Submitted batch job 3304458
# Submitted batch job 3304459
# Submitted batch job 3304460
# Submitted batch job 3304461
# Submitted batch job 3304462
# Submitted batch job 3304463
# Submitted batch job 3304464
# Submitted batch job 3304465
# Submitted batch job 3304466
# Submitted batch job 3304467
# Submitted batch job 3304468
# Submitted batch job 3304469
# Submitted batch job 3304470
# Submitted batch job 3304471
# Submitted batch job 3304472
# Submitted batch job 3304473
# Submitted batch job 3304474
# Submitted batch job 3304475
# Submitted batch job 3304476
# Submitted batch job 3304477
# Submitted batch job 3304478
# Submitted batch job 3304479
# Submitted batch job 3304480
# Submitted batch job 3304481
# Submitted batch job 3304482
# Submitted batch job 3304483
# Submitted batch job 3304484
# Submitted batch job 3304485
# Submitted batch job 3304486
# Submitted batch job 3304487
# Submitted batch job 3304488
# Submitted batch job 3304489
# Submitted batch job 3304490
# Submitted batch job 3304491
# Submitted batch job 3304492
# Submitted batch job 3304493
# Submitted batch job 3304494
# Submitted batch job 3304495
# Submitted batch job 3304496
# Submitted batch job 3304497
# Submitted batch job 3304498
# Submitted batch job 3304499
# Submitted batch job 3304500
# Submitted batch job 3304501
# Submitted batch job 3304502
# Submitted batch job 3304503
# Submitted batch job 3304504
# Submitted batch job 3304505
# Submitted batch job 3304506
# Submitted batch job 3304507
# Submitted batch job 3304508
# Submitted batch job 3304509
# Submitted batch job 3304510
# Submitted batch job 3304511
# Submitted batch job 3304512
# Submitted batch job 3304513
# Submitted batch job 3304514
# Submitted batch job 3304515
# Submitted batch job 3304516
# Submitted batch job 3304517
# Submitted batch job 3304518
# Submitted batch job 3304519
# Submitted batch job 3304520
# Submitted batch job 3304521
# Submitted batch job 3304522
# Submitted batch job 3304523
# Submitted batch job 3304524
# Submitted batch job 3304525
# Submitted batch job 3304526
# Submitted batch job 3304527
# Submitted batch job 3304528
# Submitted batch job 3304529
# Submitted batch job 3304530
# Submitted batch job 3304531
# Submitted batch job 3304532
# Submitted batch job 3304533
# Submitted batch job 3304534
# Submitted batch job 3304535
# Submitted batch job 3304536
# Submitted batch job 3304537
# Submitted batch job 3304538
# Submitted batch job 3304539
# Submitted batch job 3304540
# Submitted batch job 3304541
# Submitted batch job 3304542
# Submitted batch job 3304543
# Submitted batch job 3304544
# Submitted batch job 3304545
# Submitted batch job 3304546
# Submitted batch job 3304547
# Submitted batch job 3304548
# Submitted batch job 3304549
# Submitted batch job 3304550
# Submitted batch job 3304551
# Submitted batch job 3304552
# Submitted batch job 3304553
# Submitted batch job 3304554
# Submitted batch job 3304555
# Submitted batch job 3304556
# Submitted batch job 3304557
# Submitted batch job 3304558
# Submitted batch job 3304559
# Submitted batch job 3304560
# Submitted batch job 3304561
# Submitted batch job 3304562
# Submitted batch job 3304563
# Submitted batch job 3304564
# Submitted batch job 3304565
# Submitted batch job 3304566
# Submitted batch job 3304567
# Submitted batch job 3304568
# Submitted batch job 3304569
# Submitted batch job 3304570
# Submitted batch job 3304571
# Submitted batch job 3304572
# Submitted batch job 3304573
# Submitted batch job 3304574
# Submitted batch job 3304575
# Submitted batch job 3304576
# Submitted batch job 3304577
# Submitted batch job 3304578
# Submitted batch job 3304579
# Submitted batch job 3304580
# Submitted batch job 3304581
# Submitted batch job 3304582
# Submitted batch job 3304583
# Submitted batch job 3304584
# Submitted batch job 3304585
# Submitted batch job 3304586
# Submitted batch job 3304587
# Submitted batch job 3304588
# Submitted batch job 3304589
# Submitted batch job 3304590
# Submitted batch job 3304591
# Submitted batch job 3304592
# Submitted batch job 3304593
# Submitted batch job 3304594
# Submitted batch job 3304595
# Submitted batch job 3304596
# Submitted batch job 3304597
# Submitted batch job 3304598
# Submitted batch job 3304599
# Submitted batch job 3304600
# Submitted batch job 3304601
# Submitted batch job 3304602
# Submitted batch job 3304603
# Submitted batch job 3304604
# Submitted batch job 3304605
# Submitted batch job 3304606
# Submitted batch job 3304607
# Submitted batch job 3304608
# Submitted batch job 3304609
# Submitted batch job 3304610
# Submitted batch job 3304611
# Submitted batch job 3304612
# Submitted batch job 3304613
# Submitted batch job 3304614
# Submitted batch job 3304615
# Submitted batch job 3304616
# Submitted batch job 3304617
# Submitted batch job 3304618
# Submitted batch job 3304619
# Submitted batch job 3304620
# Submitted batch job 3304621
# Submitted batch job 3304622
# Submitted batch job 3304623
# Submitted batch job 3304624
# Submitted batch job 3304625
# Submitted batch job 3304626
# Submitted batch job 3304627
# Submitted batch job 3304628
# Submitted batch job 3304629
# Submitted batch job 3304630
# Submitted batch job 3304631
# Submitted batch job 3304632
# Submitted batch job 3304633
# Submitted batch job 3304634
# Submitted batch job 3304635
# Submitted batch job 3304636
# Submitted batch job 3304637
# Submitted batch job 3304638
# Submitted batch job 3304639
# Submitted batch job 3304640
# Submitted batch job 3304641
# Submitted batch job 3304642
# Submitted batch job 3304643
# Submitted batch job 3304644
# Submitted batch job 3304645
# Submitted batch job 3304646
# Submitted batch job 3304647
# Submitted batch job 3304648
# Submitted batch job 3304649
# Submitted batch job 3304650
# Submitted batch job 3304651
# Submitted batch job 3304652
# Submitted batch job 3304653
# Submitted batch job 3304654
# Submitted batch job 3304655
# Submitted batch job 3304656
# Submitted batch job 3304657
# Submitted batch job 3304658
# Submitted batch job 3304659
# Submitted batch job 3304660

# %%
### AUNLE                
for seed in (1, 2, 3):
    for ns in (
        (1000,),
        (10000,),
        (100000,),
    ):
        for no in list(range(1, 10)):
            for task in ("slcp", "two_moons", "lotka_volterra", "gaussian_linear_uniform",):
                _ = run_maybe_remotely(
                    run_unle,
                    folder_name="icml",
                    experience_name="aunle",
                    use_slurm=True,
                    slurm_kwargs={},
                    task=task,
                    num_samples=ns,
                    num_observation=no,
                    num_smc_steps=20,
                    num_mala_steps=3,
                    use_warm_start=True,
                    learning_rate=0.001 if task == "lotka_volterra" else 0.01,
                    max_iter=100 if task=="gaussian_linear_uniform" and (ns==(1000,) or ns==(10000,)) else 2000,
                    weight_decay=0.1,
                    random_seed=seed,
                    sampler="smc",
                    num_particles=1000,
                    batch_size=1000,
                    num_posterior_samples=10000,
                    use_nuts=False,
                    init_proposal="prior",
                    noise_injection_val=0.0005,
                    proposal="prior+noise",
                    inference_sampler="smc",
                    ebm_model_type="joint_tilted",
                    inference_proposal="prior",
                    use_data_from_past_rounds=False,
                    evaluate_posterior=True
            )
